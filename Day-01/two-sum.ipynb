# %% [markdown]
# Problem Statement:
#     - Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#     - You may assume that each input would have exactly one solution, and you may not use the same element twice.
#     - You can return the answer in any order.
#
#     Example 1:
#         Input: nums = [2,7,11,15], target = 9
#         Output: [0,1]
#         Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# reference url: https://leetcode.com/problems/two-sum/

# %%
"""
_summary_: looping approach
_complexity_: time -> O(n)
_my_experience_:
"""
from typing import List

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for idx in range(len(nums) - 1):
            if nums[idx] + nums[idx + 1] == target:
                return [idx, idx + 1]
        return []

solution_object = Solution()
print("result:", solution_object.twoSum([2, 7, 11, 15], 9))
print("result:", solution_object.twoSum([3, 2, 4], 6))
print("result:", solution_object.twoSum([3, 3], 6))
# Out:
# result: [0, 1]
# result: [1, 2]
# result: [0, 1]

# %%
"""
_summary_: Brut-force approach
_complexity_: time -> O(n^2)
_my_experience_:
"""
from typing import List

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for idx_01 in range(len(nums)):
            for idx_02 in range(idx_01 + 1, len(nums)):
                if nums[idx_01] + nums[idx_02] == target:
                    return [idx_01, idx_02]
        return []

solution_object = Solution()
print("result:", solution_object.twoSum([2, 7, 11, 15], 9))
print("result:", solution_object.twoSum([3, 2, 4], 6))
print("result:", solution_object.twoSum([3, 3], 6))
# Out:
# result: [0, 1]
# result: [1, 2]
# result: [0, 1]

# %%
"""
_summary_: Hash mapping approach
_complexity_: time -> O(n)
_my_experience_:
    - getting index while looping using enumerate
    - 
"""
from typing import List

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        if not 2 <= len(nums) <= 104:
            raise Exception("too much values in provided list")
        
        hash_map = {}
        for idx, nums_value in enumerate(nums):
            complement = target - nums_value
            print("complement: ", complement)
            if complement in hash_map:
                return [hash_map[complement], idx]
            
            hash_map[nums_value] = idx
            print("hash_map:", hash_map)
        return []

solution_object = Solution()
print("result:", solution_object.twoSum([11, 15, 2, 7], 9))
# print("result:", solution_object.twoSum([3, 2, 4], 6))
# print("result:", solution_object.twoSum([3, 3], 6))
# Out:
# complement:  -2
# hash_map: {11: 0}
# complement:  -6
# hash_map: {11: 0, 15: 1}
# complement:  7
# hash_map: {11: 0, 15: 1, 2: 2}
# complement:  2
# result: [2, 3]
