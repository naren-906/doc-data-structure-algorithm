# %%
import time

# todo: O(1) — Constant Time
""" not a big deal how huge is a list. execution time is constant """
list_of_data = [1, 'a', 2, 'b', 3, 'c', 4, 'd', 5, 'e']

def get_first_item(items) -> str | int:
    return items[-1]

print("get_first_item: ", get_first_item(list_of_data))
# Out:
# get_first_item:  e

# %%
# todo: O(n) — Linear Time
""" based on list or input length time will increase """

def get_targeted_item(list_of_data: list, target: int) -> int:
    start_time = time.time()  # ⏱️ Start timer
    
    for individual_number in list_of_data:
        if target == individual_number:
            end_time = time.time()  # ⏱️ End timer
            print(f"Execution Time: {end_time - start_time:.10f} seconds")
            return individual_number
    
    end_time = time.time()
    print(f"Execution Time: {end_time - start_time:.10f} seconds")
    return None


# Test data
print("get_targeted_item:", get_targeted_item(range(900000), 899999))
# Out:
# Execution Time: 0.0271949768 seconds
# get_targeted_item: 899999

# %%
# todo: O(n²) — Quadratic Time
""" Nested loops → time grows as n × n. """

def print_pairs(arr):
    start_time = time.time()
    empty_list = []
    for i in arr:
        for j in arr:
            empty_list.append((i,j))
    end_time = time.time()
    print(f"Execution Time: {end_time - start_time:.10f} seconds")
    return empty_list

print("Nested loop: ", print_pairs([1, 2, 3]))
# Out:
# Execution Time: 0.0000040531 seconds
# Nested loop:  [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]

# %%
# todo: O(log n) — binary search
""" The input size decreases by half each time — like divide & conquer """

def binary_search(list_of_data: list, target: int) -> int:
    start_time = time.time()  # ⏱️ Start timer
    
    if target not in list_of_data:
        return "targeted value not found"
    
    steps, low, high = 0, 0, len(list_of_data) - 1
    while low <= high:
        mid: int = (high + low)//2
        steps += 1
    
        if list_of_data[mid] == target:
            end_time = time.time()
            print(f"Execution Time: {end_time - start_time:.10f} seconds")
            return f"position of targeted value is {mid} and step {steps}"
    
        elif list_of_data[mid] < target:
            low = mid + 1
    
        elif list_of_data[mid] > target:
            high = mid - 1
    
    end_time = time.time()
    print(f"Execution Time: {end_time - start_time:.10f} seconds")
    return None

# Test data
print("binary_search: ", binary_search(range(5), 4))
# Out:
# Execution Time: 0.0000073910 seconds
# binary_search:  position of targeted value is 4 and step 3

# %%
import time

# todo: O(n log n) — Linearithmic Time
""" You do a log n operation for every n element """

def merge_sort(list_of_data: list) -> int:
    start_time = time.time()  # ⏱️ Start timer
    

    end_time = time.time()
    print(f"Execution Time: {end_time - start_time:.10f} seconds")
    return None

# Test data
print("merge_sort: ", merge_sort(range(5)))
# Out:
# Execution Time: 0.0000007153 seconds
# merge_sort:  None
